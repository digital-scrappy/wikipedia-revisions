# %%
import sqlite3
import pandas
from datetime import datetime
from bin_revison_history import month_bin_revisions

# %%
db_path = "/home/scrappy/data/csh/aggregated_edits.db"

con = sqlite3.connect(db_path)
cur = con.cursor()
cur.execute("Select * from occupations")
occ = cur.fetchone()
occ
# Out:
# (1,
#  '11-1011',
#  'Chief Executives',
#  '[["Chief executive officer", "http://en.wikipedia.org/?curid=52234"]]',
#  '[["Chief executive officer", "http://en.wikipedia.org/?curid=52234"]]',
#  '[248760, 246240, 238940, 223260, 210160, 195530, 205890, 202360, 200480]',
#  '[85.77, 86.88, 89.35, 93.44, 94.25, 96.22, 93.2, 95.12, 102.41]',
#  '[178400, 180700, 185850, 194350, 196050, 200140, 193850, 197840, 213020]',
#  '[36.07, 34.97, 32.98, 33.55, 32.74, 32.86, 29.95, 30.18, 28.99]',
#  '[53.18, 53.25, 53.38, 54.86, 54.55, 55.75, 54.23, 55.06, 53.4]',
#  '[82.5, 83.33, 84.19, 87.12, 88.11, 91.15, 88.68, 89.4, 86.31]',
#  '["#", "#", "#", "#", "#", "#", "#", "#", "#"]',
#  '["#", "#", "#", "#", "#", "#", "#", "#", "#"]',
#  '[75030, 72750, 68600, 69780, 68110, 68360, 62290, 62780, 60300]',
#  '[110610, 110760, 111040, 114100, 113470, 115960, 112790, 114530, 111080]',
#  '[171610, 173320, 175110, 181210, 183270, 189600, 184460, 185950, 179520]',
# ...

# %%
years = [datetime(year=2013+i, month=5,day=1) for i in range(9)]

# %%
# Out:
# [datetime.datetime(2013, 5, 1, 0, 0),
#  datetime.datetime(2014, 5, 1, 0, 0),
#  datetime.datetime(2015, 5, 1, 0, 0),
#  datetime.datetime(2016, 5, 1, 0, 0),
#  datetime.datetime(2017, 5, 1, 0, 0),
#  datetime.datetime(2018, 5, 1, 0, 0),
#  datetime.datetime(2019, 5, 1, 0, 0),
#  datetime.datetime(2020, 5, 1, 0, 0),
#  datetime.datetime(2021, 5, 1, 0, 0)]
